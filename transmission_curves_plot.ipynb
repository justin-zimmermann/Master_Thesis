# %%
#from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker
# %matplotlib inline
#from astropy import wcs
#from astropy.nddata import Cutout2D
#from astropy import coordinates
from astropy import units as u
#from astropy.coordinates import SkyCoord
#from astropy.wcs import WCS
#import matplotlib.gridspec as gridspec
import aplpy
import pandas as pd

# %%
t1 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F435W_b.dat', delim_whitespace=True)
t2 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F606W_v.dat', delim_whitespace=True)
t3 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F775W_i.dat', delim_whitespace=True)
t4 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F850LP_z.dat', delim_whitespace=True)
t1e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F435W_b_eazy.dat', delim_whitespace=True)
t2e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F606W_v_eazy.dat', delim_whitespace=True)
t3e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F775W_i_eazy.dat', delim_whitespace=True)
t4e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/goods/filter_curves/HST-ACS_HRC.F850LP_z_eazy.dat', delim_whitespace=True)
t5 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/candels/filter_curves/f105w.IR.tab', delim_whitespace=True)
t5e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/candels/filter_curves/f105w.IR_eazy.tab', delim_whitespace=True)
t6 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/candels/filter_curves/f125w.IR.tab', delim_whitespace=True)
t6e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/candels/filter_curves/f125w.IR_eazy.tab', delim_whitespace=True)
t7 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/candels/filter_curves/f160w.IR.tab', delim_whitespace=True)
t7e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/candels/filter_curves/f160w.IR_eazy.tab', delim_whitespace=True)
t8 = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/hugs/filter_curves/hawki_Knew.dat', delim_whitespace=True)
t8e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/hugs/filter_curves/hawki_Knew_eazy.dat', delim_whitespace=True)
t9e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/spitzer/filter_curves/spitzer36_eazy.tab', delim_whitespace=True)
t10e = pd.read_csv('/Users/justin/Documents/Master_Thesis/data/surveys/spitzer/filter_curves/spitzer45_eazy.tab', delim_whitespace=True)

# %%
g = plt.figure()
axx = g.add_subplot(111)
axx.plot(t4[t4.columns[0]], t4[t4.columns[1]], marker='', ls='-', color='olivedrab', label='Z')
axx.fill_between(t4[t4.columns[0]], t4[t4.columns[1]], 0, color='yellowgreen', alpha=0.5)
axx.plot(t4e[t4e.columns[1]], t4e[t4e.columns[2]]/max(t4e[t4e.columns[2]]), marker='', ls='-', color='olivedrab', label='Z')
axx.fill_between(t4e[t4e.columns[1]], t4e[t4e.columns[2]]/max(t4e[t4e.columns[2]]), 0, color='yellowgreen', alpha=0.5)

f = plt.figure()
ax = f.add_subplot(111)

ax.plot(t1[t1.columns[0]], t1[t1.columns[1]], marker='', ls='-', color='darkblue', label='Z')
ax.fill_between(t1[t1.columns[0]], t1[t1.columns[1]], 0, color='darkblue', alpha=0.4)
ax.plot(t2[t2.columns[0]], t2[t2.columns[1]], marker='', ls='-', color='blue', label='Z')
ax.fill_between(t2[t2.columns[0]], t2[t2.columns[1]], 0, color='blue', alpha=0.3)
ax.plot(t3[t3.columns[0]], t3[t3.columns[1]], marker='', ls='-', color='darkcyan', label='Z')
ax.fill_between(t3[t3.columns[0]], t3[t3.columns[1]], 0, color='darkcyan', alpha=0.4)
ax.plot(t4[t4.columns[0]], t4[t4.columns[1]], marker='', ls='-', color='olivedrab', label='Z')
ax.fill_between(t4[t4.columns[0]], t4[t4.columns[1]], 0, color='yellowgreen', alpha=0.5)
ax.plot(t5[t5.columns[1]], t5[t5.columns[2]]/max(t5[t5.columns[2]]), marker='', ls='-', color='orange', label='Y')
ax.fill_between(t5[t5.columns[1]], t5[t5.columns[2]]/max(t5[t5.columns[2]]), 0, color='gold', alpha=0.5)
ax.plot(t6[t6.columns[1]], t6[t6.columns[2]]/max(t6[t6.columns[2]]), marker='', ls='-', color='orangered', label='H')
ax.fill_between(t6[t6.columns[1]], t6[t6.columns[2]]/max(t6[t6.columns[2]]), 0, color='orangered', alpha=0.4)
ax.plot(t7[t7.columns[1]], t7[t7.columns[2]]/max(t7[t7.columns[2]]), marker='', ls='-', color='red', label='J')
ax.fill_between(t7[t7.columns[1]], t7[t7.columns[2]]/max(t7[t7.columns[2]]), 0, color='red', alpha=0.4)
ax.plot(t8[t8.columns[0]]*10, t8[t8.columns[1]]/max(t8[t8.columns[1]]), marker='', ls='-', color='firebrick', label='K')
ax.fill_between(t8[t8.columns[0]]*10, t8[t8.columns[1]]/max(t8[t8.columns[1]]), 0, color='firebrick', alpha=0.4)
ax.plot([912*5,912*5], [0,0.1], color='black')
ax.plot([912*6,912*6], [0,0.1], color='black')
ax.plot([912*7,912*7], [0,0.1], color='black')
ax.plot([912*8,912*8], [0,0.1], color='black')
ax.plot([912*9,912*9], [0,0.1], color='black')
ax.plot([912*10,912*10], [0,0.1], color='black')
plt.xlabel('Wavelength [$\mathrm{\AA}$]')
plt.ylabel('Filter transmission')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([3000, 28000, 0.01, 1])
plt.grid(True)
plt.legend('BVIZYJHK')
f.savefig('/Users/justin/Documents/Master_Thesis/presentation/plots/filter/filter_curves_lin.pdf')
plt.xscale('log')
plt.axis([3000, 37000, 0.01, 1])
f.savefig('/Users/justin/Documents/Master_Thesis/presentation/plots/filter/filter_curves_log.pdf')

# %%
g = plt.figure(figsize=(6,8))
ax1 = g.add_subplot(211)
jy_to_mujy = 1e6
avg_limit_mag=[27.9697783149,28.3171122618,27.7485781635,27.55449491,27.8426869364,27.6625534195,27.3779298217,26.4424989916,26.2098476556,26.0908766414]
avg_limit_flux=[]
pivot_wav=[4332.66,5963,7689.71,9177.76,10550.29,12486.05,15370.33,21460,35508,44960]
fwhm_wav=[885.20,2281.53,1515.12,1531.72,2917.03,3005.20,2874.18,3240,7432,10097]
for i in range(len(avg_limit_mag)):
    fwhm_wav[i]=fwhm_wav[i]/2.
    avg_limit_flux.append(jy_to_mujy*3631*(10**(-avg_limit_mag[i]*2./5.)))
plt.errorbar(pivot_wav,avg_limit_flux,xerr=fwhm_wav,color='black',ls='')

    
hatch_pattern=['/','','|','','\\','','-','','x']
for i in [0,2,4,6,8]:
    lab='z=%1.0f' % (i+2)
    path_sed = '/Users/justin/Documents/Master_Thesis/softwares/eazy/inputs/OUTPUT/photz_' + str(i+1) + '.temp_sed'
    cat_sed = pd.read_csv(path_sed, delim_whitespace=True, header=None, names=['Wavelength', 'Flux'], skiprows=[0,1])
    ax1.plot(cat_sed['Wavelength'], cat_sed['Flux']*jy_to_mujy, marker='', lw=1, ls='-', color=(1/((0.3*i)+1),(i)/15,1), label=lab)
    interp_limit_flux=np.interp(cat_sed['Wavelength'],pivot_wav,avg_limit_flux)
    #ax1.fill_between(cat_sed['Wavelength'], cat_sed['Flux']*jy_to_mujy, interp_limit_flux, where= interp_limit_flux <= cat_sed['Flux']*jy_to_mujy, facecolor=(1/((0.3*i)+1),(i)/15,1),alpha=0.05)
    
ax1.fill_between(cat_sed['Wavelength'], interp_limit_flux, 0, hatch='\\'*2, alpha=1, facecolor='#ededed', edgecolor='gray', lw=0)  
plt.ylabel('$F_{\\nu}$ in $\mu$Jy')
plt.xscale('log')
plt.yscale('log')
plt.setp(ax1.get_xticklabels(), visible=False)
plt.grid(True)
plt.legend(ncol=5,loc='upper center', fontsize=10)
plt.axis([3000, 55000, 9e-10*jy_to_mujy, 5e-5*jy_to_mujy])




ax = g.add_subplot(212)

ax.plot(t1e[t1e.columns[1]], t1e[t1e.columns[2]], marker='', ls='-', color=(0,0.2,0.8), label='B')
ax.fill_between(t1e[t1e.columns[1]], t1e[t1e.columns[2]], 0, color=(0,0.2,0.8), alpha=0.1)
ax.plot(t2e[t2e.columns[1]], t2e[t2e.columns[2]], marker='', ls='-', color=(0.,0,1), label='V')
ax.fill_between(t2e[t2e.columns[1]], t2e[t2e.columns[2]], 0, color=(0.,0,1), alpha=0.1)
ax.plot(t3e[t3e.columns[1]], t3e[t3e.columns[2]], marker='', ls='-', color=(0.2,0,0.8), label='i')
ax.fill_between(t3e[t3e.columns[1]], t3e[t3e.columns[2]], 0, color=(0.2,0,0.8), alpha=0.1)
ax.plot(t4e[t4e.columns[1]], t4e[t4e.columns[2]], marker='', ls='-', color=(0.4,0,0.6), label='z')
ax.fill_between(t4e[t4e.columns[1]], t4e[t4e.columns[2]], 0, color=(0.4,0,0.6), alpha=0.1)
ax.plot(t5e[t5e.columns[1]], t5e[t5e.columns[2]], marker='', ls='-', color=(0.6,0,0.4), label='Y')
ax.fill_between(t5e[t5e.columns[1]], t5e[t5e.columns[2]], 0, color=(0.6,0,0.4), alpha=0.1)
ax.plot(t6e[t6e.columns[1]], t6e[t6e.columns[2]], marker='', ls='-', color=(0.8,0,0.2), label='J')
ax.fill_between(t6e[t6e.columns[1]], t6e[t6e.columns[2]], 0, color=(0.8,0,0.2), alpha=0.1)
ax.plot(t7e[t7e.columns[1]], t7e[t7e.columns[2]], marker='', ls='-', color=(1,0,0), label='H')
ax.fill_between(t7e[t7e.columns[1]], t7e[t7e.columns[2]], 0, color=(1,0,0), alpha=0.1)
ax.plot(t8e[t8e.columns[1]], t8e[t8e.columns[2]]/max(t8e[t8e.columns[2]]), marker='', ls='-', color=(1,0.2,0), label='K$_S$')
ax.fill_between(t8e[t8e.columns[1]], t8e[t8e.columns[2]]/max(t8e[t8e.columns[2]]), 0, color=(1,0.2,0), alpha=0.1)
ax.plot(t9e[t9e.columns[1]], t9e[t9e.columns[2]], marker='', ls='-', color=(1,0.4,0), label='3.6$\mu m$')
ax.fill_between(t9e[t9e.columns[1]], t9e[t9e.columns[2]], 0, color=(1,0.4,0), alpha=0.1)
ax.plot(t10e[t10e.columns[1]], t10e[t10e.columns[2]], marker='', ls='-', color=(1,0.6,0), label='4.5$\mu m$')
ax.fill_between(t10e[t10e.columns[1]], t10e[t10e.columns[2]], 0, color=(1,0.6,0), alpha=0.1)
#ax.plot([912*6,912*6], [0,0.1], color='black')
#ax.plot([912*7,912*7], [0,0.1], color='black')
#ax.plot([912*8,912*8], [0,0.1], color='black')
#ax.plot([912*9,912*9], [0,0.1], color='black')
#ax.plot([912*10,912*10], [0,0.1], color='black')
plt.xlabel('$\lambda$ in $\AA$')
plt.ylabel('Filter transmission')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([3000, 55000, 0.0, 1.3])
plt.grid(True)
plt.subplots_adjust(hspace = 0.)
plt.legend(loc='upper center',ncol=5,fontsize=10)
plt.xscale('log')
ax.set_xticks([4000,10000,40000])
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
g.savefig('/Users/justin/Documents/Master_Thesis/presentation/plots/filter/sed_filter.pdf', dpi=1000,bbox_inches='tight')

#plt.axis([3000, 55000, 0.0, 1.5])
#f.savefig('/Users/justin/Documents/Master_Thesis/presentation/plots/filter/sed_filter_log.pdf')
